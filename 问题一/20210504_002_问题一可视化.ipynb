# %%
import pandas as pd
data=pd.read_excel("2021校内竞赛附录：data.xlsx")
print(data[data.isnull().T.any()])
print("---------------------------------")
data
# Out:
# Empty DataFrame
# Columns: [日期, 累计确诊, 治愈人数, 死亡人数]
# Index: []
# ---------------------------------
#              日期      累计确诊       治愈人数     死亡人数
# 0    2020-01-26      2011         51       56
# 1    2020-01-27      2785         60       82
# 2    2020-01-28      5344        103      131
# 3    2020-01-29      5908        126      133
# 4    2020-01-30      7893        171      171
# ..          ...       ...        ...      ...
# 456  2021-04-26  22840826  121911107  3120469
# 457  2021-04-27  22755774  122826142  3134956
# 458  2021-04-28  22914640  123557549  3150675
# 459  2021-04-29  22874247  124480554  3165665
# 460  2021-04-30  23060089  125159153  3180238
#
# [461 rows x 4 columns]

# %%
temp0=pd.read_csv('predict0.csv')
temp1=pd.read_csv('predict1.csv')
temp2=pd.read_csv('predict2.csv')
temp3=pd.read_csv('predict3.csv')
temp4=pd.read_csv('predict4.csv')
temp5=pd.read_csv('predict5.csv')
temp6=pd.read_csv('predict6.csv')
temp7=pd.read_csv('predict7.csv')
temp8=pd.read_csv('predict8.csv')
temp9=pd.read_csv('predict9.csv')
temp10=pd.read_csv('predict10.csv')
temp11=pd.read_csv('predict11.csv')
temp12=pd.read_csv('predict12.csv')
temp13=pd.read_csv('predict13.csv')
temp14=pd.read_csv('predict14.csv')
predict=pd.concat([temp0,temp1,temp2,temp3,temp4,temp5,temp6,temp7,temp8,temp9,temp10,temp11,temp12,temp13,temp14],axis=0)
predict
# Out:
#                S             E          累计确诊          治愈人数          死亡人数
# 0   7.584528e+09  6.742490e+05  2.011000e+03  5.100000e+01  5.600000e+01
# 1   7.584528e+09  6.711869e+05  5.023743e+03  9.782596e+01  6.232120e+01
# 2   7.584528e+09  6.681442e+05  7.942941e+03  2.148034e+02  7.811238e+01
# 3   7.584528e+09  6.651209e+05  1.077115e+04  3.997541e+02  1.030795e+02
# 4   7.584528e+09  6.621166e+05  1.351088e+04  6.505595e+02  1.369366e+02
# ..           ...           ...           ...           ...           ...
# 26  6.972414e+09  4.730839e+08  2.549102e+07  1.111998e+08  3.015259e+06
# 27  6.972414e+09  4.724638e+08  2.550426e+07  1.117957e+08  3.026928e+06
# 28  6.972413e+09  4.718445e+08  2.551638e+07  1.123919e+08  3.038603e+06
# 29  6.972412e+09  4.712260e+08  2.552740e+07  1.129883e+08  3.050283e+06
# 30  6.972411e+09  4.706084e+08  2.553734e+07  1.135851e+08  3.061969e+06
#
# [465 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
x=list(range(1,data.shape[0]+1))
y1=data['累计确诊'].tolist()
y2=data['治愈人数'].tolist()
y3=data['死亡人数'].tolist()
plt.plot(x,y1,'r-',label='Injected_true',linewidth = 3)
plt.plot(x,y2,'b-',label='Recovered_true',linewidth = 3)
plt.plot(x,y3,'y-',label='Dead_true',linewidth = 3)
data=predict
x_pre=list(range(1,data.shape[0]+1))
y1_pre=data['累计确诊'].tolist()
y2_pre=data['治愈人数'].tolist()
y3_pre=data['死亡人数'].tolist()
plt.plot(x_pre,y1_pre,'c-',label='Injected_predict',linewidth = 1)
plt.plot(x_pre,y2_pre,'g-',label='Recovered_predict',linewidth = 1)
plt.plot(x_pre,y3_pre,'m-',label='Dead_predict',linewidth = 1)
plt.legend()
plt.show()

# %%
plt.figure(1)
plt.plot(x,y1,'r-',label='Injected_true',linewidth = 3)
plt.plot(x_pre,y1_pre,'c-',label='Injected_predict',linewidth = 1)
plt.legend()
plt.figure(2)
plt.plot(x,y2,'b-',label='Recovered_true',linewidth = 3)
plt.plot(x_pre,y2_pre,'g-',label='Recovered_predict',linewidth = 1)
plt.legend()
plt.figure(3)
plt.plot(x,y3,'y-',label='Dead_true',linewidth = 3)
plt.plot(x_pre,y3_pre,'m-',label='Dead_predict',linewidth = 1)
plt.legend()
plt.show()

# %%
#预测数据可视化
final_origin=pd.read_csv('final_Improve.csv')
final_y1=final_origin['累计确诊'].tolist()
final_y2=final_origin['治愈人数'].tolist()
final_y3=final_origin['死亡人数'].tolist()
final_x=list(range(1,final_origin.shape[0]+1))
plt.plot(final_x,final_y1,'r-',label='Injected_Predict',linewidth = 3)
plt.plot(final_x,final_y2,'b-',label='Recovered_Predict',linewidth = 3)
plt.plot(final_x,final_y3,'y-',label='Dead_Predict',linewidth = 3)
plt.legend()
plt.show()

# %%
plt.figure(1)
plt.plot(final_x,final_y1,'r-',label='Injected_Predict',linewidth = 3)
plt.legend()
plt.show()
plt.figure(2)
plt.plot(final_x,final_y2,'b-',label='Recovered_Predict',linewidth = 3)
plt.legend()
plt.show()
plt.figure(3)
plt.plot(final_x,final_y3,'y-',label='Dead_Predict',linewidth = 3)
plt.legend()
plt.show()
