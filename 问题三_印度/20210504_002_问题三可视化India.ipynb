# %%
import pandas as pd
data=pd.read_excel("India.xlsx")
print(data[data.isnull().T.any()])
print("---------------------------------")
data
# Out:
# Empty DataFrame
# Columns: [日期, 累计确诊, 治愈人数, 死亡人数]
# Index: []
# ---------------------------------
#             日期     累计确诊      治愈人数    死亡人数
# 0   2020-03-11       57         4       1
# 1   2020-03-12       68         4       1
# 2   2020-03-13       76         4       2
# 3   2020-03-14       96         4       2
# 4   2020-03-15       98        13       2
# ..         ...      ...       ...     ...
# 413 2021-04-28  3084849  15086740  204832
# 414 2021-04-29  3170228  15384418  208330
# 415 2021-04-30  3268710  15684406  211853
# 416 2021-05-01  3349644  15992271  215542
# 417 2021-05-02  3349644  15992271  215542
#
# [418 rows x 4 columns]

# %%
temp0=pd.read_csv('third_predict0.csv')
temp1=pd.read_csv('third_predict1.csv')
temp2=pd.read_csv('third_predict2.csv')
temp3=pd.read_csv('third_predict3.csv')
temp4=pd.read_csv('third_predict4.csv')
temp5=pd.read_csv('third_predict5.csv')
temp6=pd.read_csv('third_predict6.csv')
temp7=pd.read_csv('third_predict7.csv')
temp8=pd.read_csv('third_predict8.csv')
temp9=pd.read_csv('third_predict9.csv')
temp10=pd.read_csv('third_predict10.csv')
temp11=pd.read_csv('third_predict11.csv')
temp12=pd.read_csv('third_predict12.csv')
predict=pd.concat([temp0,temp1,temp2,temp3,temp4,temp5,temp6,temp7,temp8,temp9,temp10,temp11,temp12],axis=0)
predict
# Out:
#                S             E           累计确诊          治愈人数           死亡人数
# 0   1.380004e+09  2.100000e+01      57.000000  4.000000e+00       1.000000
# 1   1.380004e+09  3.841342e+01      59.114227  7.640778e+00       1.073059
# 2   1.380004e+09  5.185621e+01      65.923394  1.141660e+01       1.148828
# 3   1.380004e+09  6.434468e+01      76.019645  1.562734e+01       1.233325
# 4   1.380004e+09  7.748396e+01      88.923959  2.048297e+01       1.330762
# ..           ...           ...            ...           ...            ...
# 26  1.349165e+09  1.857670e+07  581102.164878  1.152182e+07  159546.670641
# 27  1.348597e+09  1.908824e+07  598301.082917  1.156064e+07  159653.073625
# 28  1.348013e+09  1.961479e+07  615893.400227  1.160060e+07  159762.625826
# 29  1.347412e+09  2.015667e+07  633898.112821  1.164175e+07  159875.399275
# 30  1.346793e+09  2.071421e+07  652333.902309  1.168409e+07  159991.469487
#
# [403 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
x=list(range(1,data.shape[0]+1))
y1=data['累计确诊'].tolist()
y2=data['治愈人数'].tolist()
y3=data['死亡人数'].tolist()
plt.plot(x,y1,'r-',label='Injected_true',linewidth = 3)
plt.plot(x,y2,'b-',label='Recovered_true',linewidth = 3)
plt.plot(x,y3,'y-',label='Dead_true',linewidth = 3)
data=predict
x_pre=list(range(1,data.shape[0]+1))
y1_pre=data['累计确诊'].tolist()
y2_pre=data['治愈人数'].tolist()
y3_pre=data['死亡人数'].tolist()
plt.plot(x_pre,y1_pre,'c-',label='Injected_predict',linewidth = 1)
plt.plot(x_pre,y2_pre,'g-',label='Recovered_predict',linewidth = 1)
plt.plot(x_pre,y3_pre,'m-',label='Dead_predict',linewidth = 1)
plt.legend()
plt.show()

# %%
plt.figure(1)
plt.plot(x,y1,'r-',label='Injected_true',linewidth = 3)
plt.plot(x_pre,y1_pre,'c-',label='Injected_predict',linewidth = 1)
plt.legend()
plt.figure(2)
plt.plot(x,y2,'b-',label='Recovered_true',linewidth = 3)
plt.plot(x_pre,y2_pre,'g-',label='Recovered_predict',linewidth = 1)
plt.legend()
plt.figure(3)
plt.plot(x,y3,'y-',label='Dead_true',linewidth = 3)
plt.plot(x_pre,y3_pre,'m-',label='Dead_predict',linewidth = 1)
plt.legend()
plt.show()

# %%
#预测数据可视化
final_origin=pd.read_csv('final_Improve.csv')
final_y1=final_origin['累计确诊'].tolist()
final_y2=final_origin['治愈人数'].tolist()
final_y3=final_origin['死亡人数'].tolist()
final_x=list(range(1,final_origin.shape[0]+1))
plt.plot(final_x,final_y1,'r-',label='Injected_Predict',linewidth = 3)
plt.plot(final_x,final_y2,'b-',label='Recovered_Predict',linewidth = 3)
plt.plot(final_x,final_y3,'y-',label='Dead_Predict',linewidth = 3)
plt.legend()
plt.show()

# %%
plt.figure(1)
plt.plot(final_x,final_y1,'r-',label='Injected_Predict',linewidth = 3)
plt.legend()
plt.show()
plt.figure(2)
plt.plot(final_x,final_y2,'b-',label='Recovered_Predict',linewidth = 3)
plt.legend()
plt.show()
plt.figure(3)
plt.plot(final_x,final_y3,'y-',label='Dead_Predict',linewidth = 3)
plt.legend()
plt.show()
